# %%
# !pip install requests
# !pip install beautifulsoup4
# !pip install pandas
# !pip install geopy
# !pip install folium
# Out:
# Requirement already satisfied: requests in ./anaconda3/lib/python3.11/site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./anaconda3/lib/python3.11/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/lib/python3.11/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./anaconda3/lib/python3.11/site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.11/site-packages (from requests) (2024.7.4)
# Requirement already satisfied: beautifulsoup4 in ./anaconda3/lib/python3.11/site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in ./anaconda3/lib/python3.11/site-packages (from beautifulsoup4) (2.4)
# Requirement already satisfied: pandas in ./anaconda3/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./anaconda3/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in ./anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in ./anaconda3/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in ./anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: geopy in ./anaconda3/lib/python3.11/site-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in ./anaconda3/lib/python3.11/site-packages (from geopy) (2.0)
# Requirement already satisfied: folium in ./anaconda3/lib/python3.11/site-packages (0.17.0)
# Requirement already satisfied: branca>=0.6.0 in ./anaconda3/lib/python3.11/site-packages (from folium) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in ./anaconda3/lib/python3.11/site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in ./anaconda3/lib/python3.11/site-packages (from folium) (1.24.3)
# Requirement already satisfied: requests in ./anaconda3/lib/python3.11/site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in ./anaconda3/lib/python3.11/site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./anaconda3/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./anaconda3/lib/python3.11/site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/lib/python3.11/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./anaconda3/lib/python3.11/site-packages (from requests->folium) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.11/site-packages (from requests->folium) (2024.7.4)

# %%
import shutil
import os


file_path = '/Users/mac/Data_Scrapping.py'


file_name = os.path.basename(file_path)


destination_path = os.path.join(os.getcwd(), file_name)


shutil.move(file_path, destination_path)

print(f'The file "{file_name}" has been moved to the current directory.')
# Out:
# The file "Data_Scrapping.py" has been moved to the current directory.

# %%
import unittest
from Data_Scrapping import scrape_population_data, fetch_and_process_api_data, combine_dataframes, create_country_iframes, show_population_map
import pandas as pd

# %%
import unittest
from Data_Scrapping import scrape_population_data
import pandas as pd

class TestScraper(unittest.TestCase):
    """Unit tests for the data scraping functionality.

    This class contains tests to validate the output of the
    scrape_population_data function, ensuring that the data
    is correctly structured and saved in the expected formats.
    """

    def test_scrape_population_data(self):
        """Test that the scraped population data is not empty and has the expected columns.

        This test checks if the DataFrame returned by the 
        scrape_population_data function is not empty and 
        contains the specified columns.
        """
        df = scrape_population_data()
        
        self.assertFalse(df.empty)

        expected_columns = ['Country', 'Population 2023', 'Yearly change from 2022 to 2023',
                            'Density P/km^2', 'Migrants_net', 'Fertility_Rate', 'Median_age', 'Urban population']
        self.assertEqual(list(df.columns), expected_columns)

    def test_excel_output(self):
        """Test that the Excel output file can be read.

        This test attempts to read the 'countries_data.xlsx' file
        to ensure that it has been created successfully by the
        scraping function.
        """
        df = scrape_population_data()
        
        try:
            pd.read_excel('countries_data.xlsx')
        except FileNotFoundError:
            self.fail("Excel file not found")

    def test_csv_output(self):
        """Test that the CSV output file can be read.

        This test attempts to read the 'countries_data.csv' file
        to ensure that it has been created successfully by the
        scraping function.
        """
        df = scrape_population_data()
        
        try:
            pd.read_csv('countries_data.csv')
        except FileNotFoundError:
            self.fail("CSV file not found")

def run_tests():
    """Run all unit tests in the TestScraper class.

    This function sets up a test suite, loads the tests from
    the TestScraper class, and executes them using a test runner.
    """
    suite = unittest.TestSuite()
    loader = unittest.TestLoader()
    suite.addTests(loader.loadTestsFromTestCase(TestScraper))
    runner = unittest.TextTestRunner(verbosity=2)
    runner.run(suite)

run_tests()
# Out:
# test_csv_output (__main__.TestScraper.test_csv_output)
# Test that the CSV output file can be read. ... ok
# test_excel_output (__main__.TestScraper.test_excel_output)
# Test that the Excel output file can be read. ... ok
# test_scrape_population_data (__main__.TestScraper.test_scrape_population_data)
# Test that the scraped population data is not empty and has the expected columns. ... ok
#
# ----------------------------------------------------------------------
# Ran 3 tests in 2.236s
#
# OK

# %%
import time

class TestWebScrapingPerformance(unittest.TestCase):
    """Unit tests for the performance of web scraping functionality.

    This class contains tests to ensure that the time taken to
    execute the scrape_population_data function is within acceptable limits.
    """

    def test_scrape_population_data_performance(self):
        """Test the performance of the scrape_population_data function.

        This test measures the execution time of the scrape_population_data
        function and asserts that it completes within the specified threshold time.
        If the execution time exceeds the threshold, the test will fail.
        """
        start_time = time.time()
        scrape_population_data()
        end_time = time.time()
        execution_time = end_time - start_time

        print(f"Time taken to execute scrape_population_data: {execution_time} seconds")

        threshold_time = 10  # seconds
        
        self.assertLessEqual(execution_time, threshold_time, 
                             f"Execution time {execution_time} exceeds the threshold of {threshold_time} seconds")

def run_tests():
    """Run all unit tests in the TestWebScrapingPerformance class.

    This function sets up a test suite, loads the tests from
    the TestWebScrapingPerformance class, and executes them
    using a test runner.
    """
    suite = unittest.TestSuite()
    loader = unittest.TestLoader()
    suite.addTests(loader.loadTestsFromTestCase(TestWebScrapingPerformance))

    runner = unittest.TextTestRunner(verbosity=2)
    runner.run(suite)

run_tests()
# Out:
# test_scrape_population_data_performance (__main__.TestWebScrapingPerformance.test_scrape_population_data_performance)
# Test the performance of the scrape_population_data function. ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.700s
#
# OK
# Time taken to execute scrape_population_data: 0.698188066482544 seconds

# %%
import unittest
from Data_Scrapping import fetch_and_process_api_data
import pandas as pd

class TestAPIFetcher(unittest.TestCase):
    """Unit tests for the API data fetching and processing functionality.

    This class contains tests to validate the output of the
    fetch_and_process_api_data function, ensuring that the data
    is correctly structured and that the output files are created.
    """

    def test_fetch_and_process_api_data_not_empty(self):
        """Test that the fetched API data is not empty.

        This test checks if the DataFrame returned by the 
        fetch_and_process_api_data function is not empty.
        """
        df = fetch_and_process_api_data()
        self.assertFalse(df.empty, "The DataFrame returned by fetch_and_process_api_data is empty.")

    def test_fetch_and_process_api_data_columns(self):
        """Test that the fetched API data has the expected columns.

        This test checks if the DataFrame returned by the 
        fetch_and_process_api_data function contains the expected
        columns: 'Country' and 'GDP_2024'.
        """
        df = fetch_and_process_api_data()
        expected_columns = ['Country', 'GDP_2024']
        self.assertEqual(list(df.columns), expected_columns, "Columns mismatch in the DataFrame.")

    def test_csv_and_excel_files_creation(self):
        """Test that the CSV and Excel output files can be read.

        This test attempts to read the 'gdp_data.csv' and 'gdp_data.xlsx' files
        to ensure that they have been created successfully by the
        fetch_and_process_api_data function.
        """
        try:
            pd.read_csv('gdp_data.csv')
        except FileNotFoundError:
            self.fail("CSV file not found")

        try:
            pd.read_excel('gdp_data.xlsx')
        except FileNotFoundError:
            self.fail("Excel file not found")

def run_tests():
    """Run all unit tests in the TestAPIFetcher class.

    This function sets up a test suite, loads the tests from
    the TestAPIFetcher class, and executes them using a test runner.
    """
    suite = unittest.TestLoader().loadTestsFromTestCase(TestAPIFetcher)
    unittest.TextTestRunner(verbosity=2).run(suite)

run_tests()
# Out:
# test_csv_and_excel_files_creation (__main__.TestAPIFetcher.test_csv_and_excel_files_creation)
# Test that the CSV and Excel output files can be read. ... ok
# test_fetch_and_process_api_data_columns (__main__.TestAPIFetcher.test_fetch_and_process_api_data_columns)
# Test that the fetched API data has the expected columns. ... ok
# test_fetch_and_process_api_data_not_empty (__main__.TestAPIFetcher.test_fetch_and_process_api_data_not_empty)
# Test that the fetched API data is not empty. ... ok
#
# ----------------------------------------------------------------------
# Ran 3 tests in 9.639s
#
# OK

# %%
import unittest
import time
from Data_Scrapping import fetch_and_process_api_data

class TestAPIPerformance(unittest.TestCase):
    """Unit tests for the performance of API data fetching and processing.

    This class contains tests to ensure that the time taken to
    execute the fetch_and_process_api_data function is within acceptable limits.
    """

    def test_fetch_and_process_api_performance(self):
        """Test the performance of the fetch_and_process_api_data function.

        This test measures the execution time of the fetch_and_process_api_data
        function and asserts that it completes within the specified threshold time.
        If the execution time exceeds the threshold, the test will fail.
        """
        start_time = time.time()
        fetch_and_process_api_data()
        end_time = time.time()
        execution_time = end_time - start_time

        print(f"Time taken to execute fetch_and_process_api_data: {execution_time} seconds")

        threshold_time = 5  # seconds
        
        self.assertLessEqual(execution_time, threshold_time, 
                             f"Execution time {execution_time} exceeds the threshold of {threshold_time} seconds")

def run_tests():
    """Run all unit tests in the TestAPIPerformance class.

    This function sets up a test suite, loads the tests from
    the TestAPIPerformance class, and executes them using a test runner.
    """
    suite = unittest.TestSuite()
    loader = unittest.TestLoader()
    suite.addTests(loader.loadTestsFromTestCase(TestAPIPerformance))

    runner = unittest.TextTestRunner(verbosity=2)
    runner.run(suite)

run_tests()
# Out:
# test_fetch_and_process_api_performance (__main__.TestAPIPerformance.test_fetch_and_process_api_performance)
# Test the performance of the fetch_and_process_api_data function. ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 2.332s
#
# OK
# Time taken to execute fetch_and_process_api_data: 2.330104112625122 seconds

# %%
import unittest
from Data_Scrapping import combine_dataframes

class TestCombineDataframes(unittest.TestCase):
    """Unit tests for the data combining functionality.

    This class contains tests to validate the output of the
    combine_dataframes function, ensuring that the combined 
    DataFrame is correctly structured and not empty.
    """

    def test_combine_dataframes_not_empty(self):
        """Test that the combined DataFrame is not empty.

        This test checks if the DataFrame returned by the 
        combine_dataframes function is not empty.
        """
        combined_df = combine_dataframes()
        self.assertFalse(combined_df.empty, "The combined DataFrame is empty.")

    def test_combine_dataframes_columns(self):
        """Test that the combined DataFrame has the expected columns.

        This test checks if the combined DataFrame returned by the 
        combine_dataframes function contains the expected columns:
        'Country', 'Population 2023', 'Yearly change from 2022 to 2023',
        'Density P/km^2', 'Migrants_net', 'Fertility_Rate', 
        'Median_age', 'Urban population', and 'GDP_2024'.
        """
        combined_df = combine_dataframes()
        expected_columns = ['Country', 'Population 2023', 'Yearly change from 2022 to 2023',
                            'Density P/km^2', 'Migrants_net', 'Fertility_Rate', 'Median_age', 'Urban population',
                            'GDP_2024']

        self.assertEqual(list(combined_df.columns), expected_columns, "Columns mismatch in the combined DataFrame.")

def run_tests():
    """Run all unit tests in the TestCombineDataframes class.

    This function sets up a test suite, loads the tests from
    the TestCombineDataframes class, and executes them using 
    a test runner.
    """
    suite = unittest.TestLoader().loadTestsFromTestCase(TestCombineDataframes)
    unittest.TextTestRunner(verbosity=2).run(suite)

run_tests()
# Out:
# test_combine_dataframes_columns (__main__.TestCombineDataframes.test_combine_dataframes_columns)
# Test that the combined DataFrame has the expected columns. ... ok
# test_combine_dataframes_not_empty (__main__.TestCombineDataframes.test_combine_dataframes_not_empty)
# Test that the combined DataFrame is not empty. ... ok
#
# ----------------------------------------------------------------------
# Ran 2 tests in 9.240s
#
# OK

# %%
import unittest
from IPython.display import HTML

class TestCountryFunctions(unittest.TestCase):
    """Test suite for country-related functions."""

    def test_create_country_iframes_output_is_dict(self):
        """Test that the output of create_country_iframes is a dictionary."""
        combined_df = combine_dataframes()
        country_iframes = create_country_iframes(combined_df)
        self.assertIsInstance(country_iframes, dict)

    def test_create_country_iframes_countries_match(self):
        """Test that the countries in the country_iframes match those in the combined DataFrame."""
        combined_df = combine_dataframes()
        country_iframes = create_country_iframes(combined_df)
        countries_in_combined_df = combined_df['Country'].tolist()
        self.assertCountEqual(list(country_iframes.keys()), countries_in_combined_df)

    def test_create_country_iframes_no_empty_outputs(self):
        """Test that there are no empty outputs in country_iframes."""
        combined_df = combine_dataframes()
        country_iframes = create_country_iframes(combined_df)
        empty_countries = [country for country, iframe in country_iframes.items() if not iframe or iframe == '']
        self.assertFalse(empty_countries, f"Empty output for countries: {empty_countries}")

    def test_show_population_map_output_is_html(self):
        """Test that the output of show_population_map is of HTML type."""
        combined_df = combine_dataframes()
        country_iframes = create_country_iframes(combined_df)
        html_output = show_population_map(combined_df, country_iframes)
        self.assertIsInstance(html_output, HTML)

    def test_show_population_map_countries_match(self):
        """Test that the countries in the population map output match those in the combined DataFrame."""
        combined_df = combine_dataframes()
        country_iframes = create_country_iframes(combined_df)
        countries_in_combined_df = combined_df['Country'].tolist()
        countries_in_output = [country for country, iframe in country_iframes.items() if iframe]
        self.assertCountEqual(countries_in_output, countries_in_combined_df)

    def test_show_population_map_no_empty_outputs(self):
        """Test that there are no empty outputs in the population map."""
        combined_df = combine_dataframes()
        country_iframes = create_country_iframes(combined_df)
        empty_countries = [country for country, iframe in country_iframes.items() if not iframe or iframe == '']
        self.assertFalse(empty_countries, f"Empty output for countries: {empty_countries}")

def run_tests():
    """Run the test suite for country functions."""
    suite = unittest.TestLoader().loadTestsFromTestCase(TestCountryFunctions)
    unittest.TextTestRunner(verbosity=2).run(suite)

run_tests()
# Out:
# test_create_country_iframes_countries_match (__main__.TestCountryFunctions.test_create_country_iframes_countries_match)
# Test that the countries in the country_iframes match those in the combined DataFrame. ... ok
# test_create_country_iframes_no_empty_outputs (__main__.TestCountryFunctions.test_create_country_iframes_no_empty_outputs)
# Test that there are no empty outputs in country_iframes. ... ok
# test_create_country_iframes_output_is_dict (__main__.TestCountryFunctions.test_create_country_iframes_output_is_dict)
# Test that the output of create_country_iframes is a dictionary. ... ok
# test_show_population_map_countries_match (__main__.TestCountryFunctions.test_show_population_map_countries_match)
# Test that the countries in the population map output match those in the combined DataFrame. ... ok
# test_show_population_map_no_empty_outputs (__main__.TestCountryFunctions.test_show_population_map_no_empty_outputs)
# Test that there are no empty outputs in the population map. ... ok
# test_show_population_map_output_is_html (__main__.TestCountryFunctions.test_show_population_map_output_is_html)
# Test that the output of show_population_map is of HTML type. ... ok
#
# ----------------------------------------------------------------------
# Ran 6 tests in 620.261s
#
# OK

# %%
import unittest
import time

class TestPerformance(unittest.TestCase):
    """Test suite for performance-related functions."""

    def test_create_country_iframes_performance(self):
        """Test the performance of the create_country_iframes function."""
        combined_df = combine_dataframes()

        # Measure execution time
        start_time = time.time()
        create_country_iframes(combined_df) 
        end_time = time.time()
        execution_time = end_time - start_time

        print(f"Time taken to execute create_country_iframes: {execution_time} seconds")

        
        threshold_time = 60 

        
        self.assertLessEqual(execution_time, threshold_time, 
                             f"Execution time {execution_time} exceeds the threshold of {threshold_time} seconds")

    def test_show_population_map_performance(self):
        """Test the performance of the show_population_map function."""
        combined_df = combine_dataframes()
        country_iframes = create_country_iframes(combined_df)

        
        start_time = time.time()
        show_population_map(combined_df, country_iframes)
        end_time = time.time()
        execution_time = end_time - start_time

        print(f"Time taken to execute show_population_map: {execution_time} seconds")

        
        threshold_time = 60 

        
        self.assertLessEqual(execution_time, threshold_time, 
                             f"Execution time {execution_time} exceeds the threshold of {threshold_time} seconds")

def run_tests():
    """Run the test suite for performance tests."""
    suite = unittest.TestSuite()
    loader = unittest.TestLoader()
    suite.addTests(loader.loadTestsFromTestCase(TestPerformance))

    runner = unittest.TextTestRunner(verbosity=2)
    runner.run(suite)

run_tests()
# Out:
# test_create_country_iframes_performance (__main__.TestPerformance.test_create_country_iframes_performance)
# Test the performance of the create_country_iframes function. ... FAIL
# test_show_population_map_performance (__main__.TestPerformance.test_show_population_map_performance)
# Test the performance of the show_population_map function. ...
# Time taken to execute create_country_iframes: 92.3450620174408 seconds
# FAIL
#
# ======================================================================
# FAIL: test_create_country_iframes_performance (__main__.TestPerformance.test_create_country_iframes_performance)
# Test the performance of the create_country_iframes function.
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/2d/stnmmm793s99xd3p4j8nz8nc0000gn/T/ipykernel_15804/2910764503.py", line 23, in test_create_country_iframes_performance
#     self.assertLessEqual(execution_time, threshold_time,
# AssertionError: 92.3450620174408 not less than or equal to 60 : Execution time 92.3450620174408 exceeds the threshold of 60 seconds
#
# ======================================================================
# FAIL: test_show_population_map_performance (__main__.TestPerformance.test_show_population_map_performance)
# Test the performance of the show_population_map function.
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/2d/stnmmm793s99xd3p4j8nz8nc0000gn/T/ipykernel_15804/2910764503.py", line 43, in test_show_population_map_performance
#     self.assertLessEqual(execution_time, threshold_time,
# AssertionError: 84.76566100120544 not less than or equal to 60 : Execution time 84.76566100120544 exceeds the threshold of 60 seconds
#
# ----------------------------------------------------------------------
# Ran 2 tests in 274.029s
#
# FAILED (failures=2)
# Time taken to execute show_population_map: 84.76566100120544 seconds

# %%
import shutil
import os


file_path = '/Users/mac/Main_script.py'


file_name = os.path.basename(file_path)


destination_path = os.path.join(os.getcwd(), file_name)


shutil.move(file_path, destination_path)

print(f'The file "{file_name}" has been moved to the current directory.')
# Out:
# The file "Main_script.py" has been moved to the current directory.

# %%
from Main_script import clean_data, get_highest_population_countries, get_lowest_population_countries, get_top_crowded_countries, get_least_crowded_countries, get_highest_migrant_countries, get_lowest_migrant_countries, get_highest_fertility_countries, get_lowest_fertility_countries, get_oldest_countries, get_youngest_countries, get_richest_countries, get_most_poor_countries, create_dashboard

# %%
class TestCleanData(unittest.TestCase):
    """Test suite for data cleaning functions."""

    def test_cleaned_data_no_na_values(self):
        """Test that the cleaned DataFrame does not contain any NA values."""
        cleaned_df = clean_data() 
        has_na_values = cleaned_df.isnull().values.any()
        
        
        self.assertFalse(has_na_values, "NA values still present in the cleaned DataFrame.")

def run_tests():
    """Run the test suite for data cleaning tests."""
    suite = unittest.TestLoader().loadTestsFromTestCase(TestCleanData)
    unittest.TextTestRunner(verbosity=2).run(suite)

run_tests()
# Out:
# test_cleaned_data_no_na_values (__main__.TestCleanData.test_cleaned_data_no_na_values)
# Test that the cleaned DataFrame does not contain any NA values. ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.010s
#
# OK

# %%
import unittest
import pandas as pd


class TestPopulationFunctions(unittest.TestCase):
    """Test suite for functions related to population data."""

    def test_get_highest_population_countries(self):
        """Test that the function returns the countries with the highest populations."""
        cleaned_combined_data = clean_data()  
        combined_df = combine_dataframes()     
        country_iframes = create_country_iframes(combined_df) 

        
        top_countries = get_highest_population_countries(cleaned_combined_data, country_iframes)

        
        top_original_countries = cleaned_combined_data.nlargest(10, 'Population 2023')['Country'].tolist()

        
        self.assertListEqual(top_countries['Country'].tolist(), top_original_countries, "Top countries mismatch.")

    def test_get_lowest_population_countries(self):
        """Test that the function returns the countries with the lowest populations."""
        cleaned_combined_data = clean_data()  
        combined_df = combine_dataframes()      
        country_iframes = create_country_iframes(combined_df)  

        
        low_countries = get_lowest_population_countries(cleaned_combined_data, country_iframes)

        
        low_original_countries = cleaned_combined_data.nsmallest(10, 'Population 2023')['Country'].tolist()

        
        self.assertListEqual(low_countries['Country'].tolist(), low_original_countries, "Low countries mismatch.")

def run_tests():
    """Run the test suite for population-related functions."""
    suite = unittest.TestLoader().loadTestsFromTestCase(TestPopulationFunctions)
    unittest.TextTestRunner(verbosity=2, buffer=True).run(suite)

run_tests()
# Out:
# test_get_highest_population_countries (__main__.TestPopulationFunctions.test_get_highest_population_countries)
# Test that the function returns the countries with the highest populations. ...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2a4a4b9c6d5b92202d461610880cef44 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2a4a4b9c6d5b92202d461610880cef44&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2a4a4b9c6d5b92202d461610880cef44 = L.map(
#                 &quot;map_2a4a4b9c6d5b92202d461610880cef44&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b8a04c1ac73a1021fc8c319c8e8f3300 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b8a04c1ac73a1021fc8c319c8e8f3300.addTo(map_2a4a4b9c6d5b92202d461610880cef44);
#
#
#             var marker_cfb9762dff37da40d35c5d05aa6ce1b8 = L.marker(
#                 [22.3511148, 78.6677428],
#                 {}
#             ).addTo(map_2a4a4b9c6d5b92202d461610880cef44);
#
#
#         var popup_84844e237644dc799b64bd14f6b44d7b = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_4bb0577c5b40f8b511c093afa28337a8 = $(`&lt;div id=&quot;html_4bb0577c5b40f8b511c093afa28337a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;India&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17c48e110&gt;&lt;/div&gt;`)[0];
#                 popup_84844e237644dc799b64bd14f6b44d7b.setContent(html_4bb0577c5b40f8b511c093afa28337a8);
#
#
#
#         marker_cfb9762dff37da40d35c5d05aa6ce1b8.bindPopup(popup_84844e237644dc799b64bd14f6b44d7b)
#         ;
#
#
#
#
#             var marker_c153c912742d131505e4f07182f8c04c = L.marker(
#                 [39.7837304, -100.445882],
#                 {}
#             ).addTo(map_2a4a4b9c6d5b92202d461610880cef44);
#
#
#         var popup_02d79b4a2d0f120700d7ac9810a52aa0 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_c30a5d43337b4f3bd830338f037e3a94 = $(`&lt;div id=&quot;html_c30a5d43337b4f3bd830338f037e3a94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;United States&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17ca450d0&gt;&lt;/div&gt;`)[0];
#                 popup_02d79b4a2d0f120700d7ac9810a52aa0.setContent(html_c30a5d43337b4f3bd830338f037e3a94);
#
#
#
#         marker_c153c912742d131505e4f07182f8c04c.bindPopup(popup_02d79b4a2d0f120700d7ac9810a52aa0)
#         ;
#
#
#
#
#             var marker_6355c4268cfd1ddd43341618d405107e = L.marker(
#                 [-2.4833826, 117.8902853],
#                 {}
#             ).addTo(map_2a4a4b9c6d5b92202d461610880cef44);
#
#
#         var popup_980377bc4520232b34cecf9f8da608a7 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_b31a5ec1894912fdcef61506663d9f7e = $(`&lt;div id=&quot;html_b31a5ec1894912fdcef61506663d9f7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Indonesia&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17af515d0&gt;&lt;/div&gt;`)[0];
#                 popup_980377bc4520232b34cecf9f8da608a7.setContent(html_b31a5ec1894912fdcef61506663d9f7e);
#
#
#
#         marker_6355c4268cfd1ddd43341618d405107e.bindPopup(popup_980377bc4520232b34cecf9f8da608a7)
#         ;
#
#
#
#
#             var marker_fb6237b9d3f623220386603bf45014cb = L.marker(
#                 [30.3308401, 71.247499],
#                 {}
#             ).addTo(map_2a4a4b9c6d5b92202d461610880cef44);
#
#
#         var popup_08e4b1c2259a3a687895ad0a5cb763de = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_0efd202583435963dce3f749b2eb2399 = $(`&lt;div id=&quot;html_0efd202583435963dce3f749b2eb2399&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Pakistan&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17b3dc990&gt;&lt;/div&gt;`)[0];
#                 popup_08e4b1c2259a3a687895ad0a5cb763de.setContent(html_0efd202583435963dce3f749b2eb2399);
#
#
#
#         marker_fb6237b9d3f623220386603bf45014cb.bindPopup(popup_08e4b1c2259a3a687895ad0a5cb763de)
#         ;
#
#
#
#
#             var marker_9650d3ac4b7c96601c05f4183b356b35 = L.marker(
#                 [9.6000359, 7.9999721],
#                 {}
#             ).addTo(map_2a4a4b9c6d5b92202d461610880cef44);
#
#
#         var popup_60f7fe13ba043fc72ca7753711d9436f = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_08977a48be9dd2640e0f7180b30159cd = $(`&lt;div id=&quot;html_08977a48be9dd2640e0f7180b30159cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Nigeria&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17b32ff50&gt;&lt;/div&gt;`)[0];
#                 popup_60f7fe13ba043fc72ca7753711d9436f.setContent(html_08977a48be9dd2640e0f7180b30159cd);
# ok
# test_get_lowest_population_countries (__main__.TestPopulationFunctions.test_get_lowest_population_countries)
# Test that the function returns the countries with the lowest populations. ...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1e5ab27d93c99f3e1db63bd1a6520899 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1e5ab27d93c99f3e1db63bd1a6520899&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1e5ab27d93c99f3e1db63bd1a6520899 = L.map(
#                 &quot;map_1e5ab27d93c99f3e1db63bd1a6520899&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_30da0bd4b2c2600ca3262c6a9ac3d216 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_30da0bd4b2c2600ca3262c6a9ac3d216.addTo(map_1e5ab27d93c99f3e1db63bd1a6520899);
#
#
#             var marker_124e307727b9c9b89ae08c3185a195f9 = L.marker(
#                 [-8.6405212, 179.1582918181797],
#                 {}
#             ).addTo(map_1e5ab27d93c99f3e1db63bd1a6520899);
#
#
#         var popup_e2afccff1f5e3ac5de56aa66251603f8 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_2b76c449dbce0c9a0a8582c8fbe4b89e = $(`&lt;div id=&quot;html_2b76c449dbce0c9a0a8582c8fbe4b89e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Tuvalu&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17b322c50&gt;&lt;/div&gt;`)[0];
#                 popup_e2afccff1f5e3ac5de56aa66251603f8.setContent(html_2b76c449dbce0c9a0a8582c8fbe4b89e);
#
#
#
#         marker_124e307727b9c9b89ae08c3185a195f9.bindPopup(popup_e2afccff1f5e3ac5de56aa66251603f8)
#         ;
#
#
#
#
#             var marker_2cf2670ecd991062b9e6e95a507f5b29 = L.marker(
#                 [-0.5252306, 166.9324426],
#                 {}
#             ).addTo(map_1e5ab27d93c99f3e1db63bd1a6520899);
#
#
#         var popup_b8045ec294a4884ea28432b38e542aea = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_1e792665a3c518d8d72948a4c08290d9 = $(`&lt;div id=&quot;html_1e792665a3c518d8d72948a4c08290d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Nauru&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17c4d8cd0&gt;&lt;/div&gt;`)[0];
#                 popup_b8045ec294a4884ea28432b38e542aea.setContent(html_1e792665a3c518d8d72948a4c08290d9);
#
#
#
#         marker_2cf2670ecd991062b9e6e95a507f5b29.bindPopup(popup_b8045ec294a4884ea28432b38e542aea)
#         ;
#
#
#
#
#             var marker_e1077be234a548013d71b00319cfacbe = L.marker(
#                 [43.9458623, 12.458306],
#                 {}
#             ).addTo(map_1e5ab27d93c99f3e1db63bd1a6520899);
#
#
#         var popup_b0d932a578e0b2c3e8190a58136bdc4d = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_9aa46735eb735e8dc8945a821ff4e989 = $(`&lt;div id=&quot;html_9aa46735eb735e8dc8945a821ff4e989&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;San Marino&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17ce02290&gt;&lt;/div&gt;`)[0];
#                 popup_b0d932a578e0b2c3e8190a58136bdc4d.setContent(html_9aa46735eb735e8dc8945a821ff4e989);
#
#
#
#         marker_e1077be234a548013d71b00319cfacbe.bindPopup(popup_b0d932a578e0b2c3e8190a58136bdc4d)
#         ;
#
#
#
#
#             var marker_d99d3eb59a4c5576098b4f6e858afeb5 = L.marker(
#                 [15.4113138, -61.3653618],
#                 {}
#             ).addTo(map_1e5ab27d93c99f3e1db63bd1a6520899);
#
#
#         var popup_6b119ea520aed5e6993a5b3b89aa6806 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_de8d0669d2660c05e29e996be9363cd7 = $(`&lt;div id=&quot;html_de8d0669d2660c05e29e996be9363cd7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Dominica&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17c2791d0&gt;&lt;/div&gt;`)[0];
#                 popup_6b119ea520aed5e6993a5b3b89aa6806.setContent(html_de8d0669d2660c05e29e996be9363cd7);
#
#
#
#         marker_d99d3eb59a4c5576098b4f6e858afeb5.bindPopup(popup_6b119ea520aed5e6993a5b3b89aa6806)
#         ;
#
#
#
#
#             var marker_72900ef51556283ce4089cc240ebf96b = L.marker(
#                 [42.5407167, 1.5732033],
#                 {}
#             ).addTo(map_1e5ab27d93c99f3e1db63bd1a6520899);
#
#
#         var popup_1062b03aba23373d5e0a90d58cb2d1d2 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_070578f52af2e335ff1e265f9c65ff45 = $(`&lt;div id=&quot;html_070578f52af2e335ff1e265f9c65ff45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Andorra&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17cb04550&gt;&lt;/div&gt;`)[0];
#                 popup_1062b03aba23373d5e0a90d58cb2d1d2.setContent(html_070578f52af2e335ff1e265f9c65ff45);
# ok
#
# ----------------------------------------------------------------------
# Ran 2 tests in 198.599s
#
# OK

# %%
class TestPopulationFunctions(unittest.TestCase):
    """
    Unit tests for population-related functions.
    """

    def test_get_top_crowded_countries(self):
        """
        Tests the retrieval of the top 10 most crowded countries based on population density.
        """
        cleaned_combined_data = clean_data()
        combined_df = combine_dataframes()
        country_iframes = create_country_iframes(combined_df)

        top_countries = get_top_crowded_countries(cleaned_combined_data, country_iframes)

        top_original_countries = cleaned_combined_data.nlargest(10, 'Density P/km^2')['Country'].tolist()

        self.assertListEqual(top_countries['Country'].tolist(), top_original_countries, "Top countries mismatch.")

    def test_get_lowest_population_countries(self):
        """
        Tests the retrieval of the bottom 10 least crowded countries based on population density.
        """
        cleaned_combined_data = clean_data()
        combined_df = combine_dataframes()
        country_iframes = create_country_iframes(combined_df)

        low_countries = get_least_crowded_countries(cleaned_combined_data, country_iframes)

        low_original_countries = cleaned_combined_data.nsmallest(10, 'Density P/km^2')['Country'].tolist()

        self.assertListEqual(low_countries['Country'].tolist(), low_original_countries, "Low countries mismatch.")

def run_tests():
    """
    Runs all tests in the TestPopulationFunctions class.
    """
    suite = unittest.TestLoader().loadTestsFromTestCase(TestPopulationFunctions)
    unittest.TextTestRunner(verbosity=2, buffer=True).run(suite)

run_tests()
# Out:
# test_get_lowest_population_countries (__main__.TestPopulationFunctions.test_get_lowest_population_countries)
# Tests the retrieval of the bottom 10 least crowded countries based on population density. ...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1fa0f8eecaaa1aeea897744400f4d842 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1fa0f8eecaaa1aeea897744400f4d842&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1fa0f8eecaaa1aeea897744400f4d842 = L.map(
#                 &quot;map_1fa0f8eecaaa1aeea897744400f4d842&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b8718907ba1110aa8f1570909864d6c5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b8718907ba1110aa8f1570909864d6c5.addTo(map_1fa0f8eecaaa1aeea897744400f4d842);
#
#
#             var marker_92b2d016e72469c6a740feff660c0a67 = L.marker(
#                 [-0.2864982, 36.0514231],
#                 {}
#             ).addTo(map_1fa0f8eecaaa1aeea897744400f4d842);
#
#
#         var popup_502b718055469b762c49ebfb1bfaa523 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_dee38371fb0f49ed4c3e686fb3acb182 = $(`&lt;div id=&quot;html_dee38371fb0f49ed4c3e686fb3acb182&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Bangladesh&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17caf7710&gt;&lt;/div&gt;`)[0];
#                 popup_502b718055469b762c49ebfb1bfaa523.setContent(html_dee38371fb0f49ed4c3e686fb3acb182);
#
#
#
#         marker_92b2d016e72469c6a740feff660c0a67.bindPopup(popup_502b718055469b762c49ebfb1bfaa523)
#         ;
#
#
#
#
#             var marker_cbacb11b5cdf0dac8ef08984f3d003bd = L.marker(
#                 [35.8885993, 14.4476911],
#                 {}
#             ).addTo(map_1fa0f8eecaaa1aeea897744400f4d842);
#
#
#         var popup_5a147c1b46b2622e6d3e876b479d4d8c = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_cd6ba31cff7f64d2e42f5b1fcfef7de6 = $(`&lt;div id=&quot;html_cd6ba31cff7f64d2e42f5b1fcfef7de6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Malta&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17c2dbe50&gt;&lt;/div&gt;`)[0];
#                 popup_5a147c1b46b2622e6d3e876b479d4d8c.setContent(html_cd6ba31cff7f64d2e42f5b1fcfef7de6);
#
#
#
#         marker_cbacb11b5cdf0dac8ef08984f3d003bd.bindPopup(popup_5a147c1b46b2622e6d3e876b479d4d8c)
#         ;
#
#
#
#
#             var marker_ecc53e7e68d9a1e275b42a5087adaf85 = L.marker(
#                 [3.7203503, 73.2244152],
#                 {}
#             ).addTo(map_1fa0f8eecaaa1aeea897744400f4d842);
#
#
#         var popup_b074f1e55d9996add34a1c2c9679f02d = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_e3b37ae820763f0b328b244ea5359eaf = $(`&lt;div id=&quot;html_e3b37ae820763f0b328b244ea5359eaf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Maldives&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17d025c10&gt;&lt;/div&gt;`)[0];
#                 popup_b074f1e55d9996add34a1c2c9679f02d.setContent(html_e3b37ae820763f0b328b244ea5359eaf);
#
#
#
#         marker_ecc53e7e68d9a1e275b42a5087adaf85.bindPopup(popup_b074f1e55d9996add34a1c2c9679f02d)
#         ;
#
#
#
#
#             var marker_ba0c9be8ff1b63a35b58b94d44f6d496 = L.marker(
#                 [43.9382593, -79.2235563],
#                 {}
#             ).addTo(map_1fa0f8eecaaa1aeea897744400f4d842);
#
#
#         var popup_9f5825aa213a2d8448c909dacb1c7f42 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_1caadf43c75ff578f7ebb0d9350ee9b6 = $(`&lt;div id=&quot;html_1caadf43c75ff578f7ebb0d9350ee9b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Mongolia&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17c28f910&gt;&lt;/div&gt;`)[0];
#                 popup_9f5825aa213a2d8448c909dacb1c7f42.setContent(html_1caadf43c75ff578f7ebb0d9350ee9b6);
#
#
#
#         marker_ba0c9be8ff1b63a35b58b94d44f6d496.bindPopup(popup_9f5825aa213a2d8448c909dacb1c7f42)
#         ;
#
#
#
#
#             var marker_dab93e8d713e8013145710d618ca4cf3 = L.marker(
#                 [-24.7761086, 134.755],
#                 {}
#             ).addTo(map_1fa0f8eecaaa1aeea897744400f4d842);
#
#
#         var popup_a085410ceffd98dd171443dd76aec460 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_92344e744b230b20825aefcf114f53ed = $(`&lt;div id=&quot;html_92344e744b230b20825aefcf114f53ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Australia&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17c28e610&gt;&lt;/div&gt;`)[0];
#                 popup_a085410ceffd98dd171443dd76aec460.setContent(html_92344e744b230b20825aefcf114f53ed);
# ok
# test_get_top_crowded_countries (__main__.TestPopulationFunctions.test_get_top_crowded_countries)
# Tests the retrieval of the top 10 most crowded countries based on population density. ...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_710cb61d48c64bccf623afeb6ed710b5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_710cb61d48c64bccf623afeb6ed710b5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_710cb61d48c64bccf623afeb6ed710b5 = L.map(
#                 &quot;map_710cb61d48c64bccf623afeb6ed710b5&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ce8b173ea2e60699e927b1676b6b2d8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8ce8b173ea2e60699e927b1676b6b2d8.addTo(map_710cb61d48c64bccf623afeb6ed710b5);
#
#
#             var marker_e5800959da3a8751367112f290630407 = L.marker(
#                 [13.1500331, -59.5250305],
#                 {}
#             ).addTo(map_710cb61d48c64bccf623afeb6ed710b5);
#
#
#         var popup_e372e32052227bd9193b994e0e16447c = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_e5e0231c66d564278226287996de52ca = $(`&lt;div id=&quot;html_e5e0231c66d564278226287996de52ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Barbados&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17c12af90&gt;&lt;/div&gt;`)[0];
#                 popup_e372e32052227bd9193b994e0e16447c.setContent(html_e5e0231c66d564278226287996de52ca);
#
#
#
#         marker_e5800959da3a8751367112f290630407.bindPopup(popup_e372e32052227bd9193b994e0e16447c)
#         ;
#
#
#
#
#             var marker_34aca3f9cf03e6fa25a634278a603277 = L.marker(
#                 [-20.2759451, 57.5703566],
#                 {}
#             ).addTo(map_710cb61d48c64bccf623afeb6ed710b5);
#
#
#         var popup_88365e1cac3cef6ac51c87a862301ba5 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_a957888ef2f21368d6e947fe664390f6 = $(`&lt;div id=&quot;html_a957888ef2f21368d6e947fe664390f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Mauritius&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17ced6f10&gt;&lt;/div&gt;`)[0];
#                 popup_88365e1cac3cef6ac51c87a862301ba5.setContent(html_a957888ef2f21368d6e947fe664390f6);
#
#
#
#         marker_34aca3f9cf03e6fa25a634278a603277.bindPopup(popup_88365e1cac3cef6ac51c87a862301ba5)
#         ;
#
#
#
#
#             var marker_903feb793ee262f2aa139bdf9e090b5d = L.marker(
#                 [12.5013629, -69.9618475],
#                 {}
#             ).addTo(map_710cb61d48c64bccf623afeb6ed710b5);
#
#
#         var popup_41a8b3d4d88eac08853c5de03b8727ee = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_a961c166dbd4b70e3f0ebef5d627d04a = $(`&lt;div id=&quot;html_a961c166dbd4b70e3f0ebef5d627d04a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Aruba&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x1785bd450&gt;&lt;/div&gt;`)[0];
#                 popup_41a8b3d4d88eac08853c5de03b8727ee.setContent(html_a961c166dbd4b70e3f0ebef5d627d04a);
#
#
#
#         marker_903feb793ee262f2aa139bdf9e090b5d.bindPopup(popup_41a8b3d4d88eac08853c5de03b8727ee)
#         ;
#
#
#
#
#             var marker_9c9f8eac92676ebe73f082640dc9c06e = L.marker(
#                 [-0.5252306, 166.9324426],
#                 {}
#             ).addTo(map_710cb61d48c64bccf623afeb6ed710b5);
#
#
#         var popup_e9fe230946e7d04d352b7b5ccb2559e3 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_055772d89fac786b6fdd0ad495107881 = $(`&lt;div id=&quot;html_055772d89fac786b6fdd0ad495107881&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Nauru&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17c0ba7d0&gt;&lt;/div&gt;`)[0];
#                 popup_e9fe230946e7d04d352b7b5ccb2559e3.setContent(html_055772d89fac786b6fdd0ad495107881);
#
#
#
#         marker_9c9f8eac92676ebe73f082640dc9c06e.bindPopup(popup_e9fe230946e7d04d352b7b5ccb2559e3)
#         ;
#
#
#
#
#             var marker_6d9b230edf5b79df957128224f86a981 = L.marker(
#                 [-1.9646631, 30.0644358],
#                 {}
#             ).addTo(map_710cb61d48c64bccf623afeb6ed710b5);
#
#
#         var popup_c04dd620f3ec423f6f38d4dffcde26ad = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_c67ca4fd3e07212f9501aa2343cd1cea = $(`&lt;div id=&quot;html_c67ca4fd3e07212f9501aa2343cd1cea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Rwanda&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x1785bc9d0&gt;&lt;/div&gt;`)[0];
#                 popup_c04dd620f3ec423f6f38d4dffcde26ad.setContent(html_c67ca4fd3e07212f9501aa2343cd1cea);
#
#
#
#         m
# ok
#
# ----------------------------------------------------------------------
# Ran 2 tests in 198.249s
#
# OK

# %%
class TestPopulationFunctions(unittest.TestCase):
    """
    Unit tests for population-related functions, specifically focusing on migrant data.
    """

    def test_get_highest_migrant_countries(self):
        """
        Tests the retrieval of the top 10 countries with the highest net migrants.
        """
        cleaned_combined_data = clean_data()
        combined_df = combine_dataframes()
        country_iframes = create_country_iframes(combined_df)

        top_countries = get_highest_migrant_countries(cleaned_combined_data, country_iframes)

        top_original_countries = cleaned_combined_data.nlargest(10, 'Migrants_net')['Country'].tolist()

        self.assertListEqual(top_countries['Country'].tolist(), top_original_countries, "Top countries mismatch.")

    def test_get_lowest_migrant_countries(self):
        """
        Tests the retrieval of the bottom 10 countries with the lowest net migrants.
        """
        cleaned_combined_data = clean_data()
        combined_df = combine_dataframes()
        country_iframes = create_country_iframes(combined_df)

        low_countries = get_lowest_migrant_countries(cleaned_combined_data, country_iframes)

        low_original_countries = cleaned_combined_data.nsmallest(10, 'Migrants_net')['Country'].tolist()

        self.assertListEqual(low_countries['Country'].tolist(), low_original_countries, "Low countries mismatch.")

def run_tests():
    """
    Runs all tests in the TestPopulationFunctions class.
    """
    suite = unittest.TestLoader().loadTestsFromTestCase(TestPopulationFunctions)
    unittest.TextTestRunner(verbosity=2, buffer=True).run(suite)

run_tests()
# Out:
# test_get_highest_migrant_countries (__main__.TestPopulationFunctions.test_get_highest_migrant_countries)
# Tests the retrieval of the top 10 countries with the highest net migrants. ...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5a74b5ad09a20b565cbc208db93f578b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5a74b5ad09a20b565cbc208db93f578b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5a74b5ad09a20b565cbc208db93f578b = L.map(
#                 &quot;map_5a74b5ad09a20b565cbc208db93f578b&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7d3005c23dba7f025a0d904208aab5b7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7d3005c23dba7f025a0d904208aab5b7.addTo(map_5a74b5ad09a20b565cbc208db93f578b);
#
#
#             var marker_170a63abc8aed8b08faaadbfc07293b7 = L.marker(
#                 [42.5407167, 1.5732033],
#                 {}
#             ).addTo(map_5a74b5ad09a20b565cbc208db93f578b);
#
#
#         var popup_8cf71c9a8bac6a25c3a100297e55fded = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_b8494d7ea923b611467705a1f2205c40 = $(`&lt;div id=&quot;html_b8494d7ea923b611467705a1f2205c40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Andorra&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17c8e3a50&gt;&lt;/div&gt;`)[0];
#                 popup_8cf71c9a8bac6a25c3a100297e55fded.setContent(html_b8494d7ea923b611467705a1f2205c40);
#
#
#
#         marker_170a63abc8aed8b08faaadbfc07293b7.bindPopup(popup_8cf71c9a8bac6a25c3a100297e55fded)
#         ;
#
#
#
#
#             var marker_e8499ce730f211e59755f934815100b3 = L.marker(
#                 [10.2735633, -84.0739102],
#                 {}
#             ).addTo(map_5a74b5ad09a20b565cbc208db93f578b);
#
#
#         var popup_825a3c51aa121062babd6b099ea94647 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_740828b696b03af257a9a521161d8e55 = $(`&lt;div id=&quot;html_740828b696b03af257a9a521161d8e55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Costa Rica&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17be65ed0&gt;&lt;/div&gt;`)[0];
#                 popup_825a3c51aa121062babd6b099ea94647.setContent(html_740828b696b03af257a9a521161d8e55);
#
#
#
#         marker_e8499ce730f211e59755f934815100b3.bindPopup(popup_825a3c51aa121062babd6b099ea94647)
#         ;
#
#
#
#
#             var marker_6fadc07c397b4749d5a56c63e5c1b7c3 = L.marker(
#                 [42.6073975, 25.4856617],
#                 {}
#             ).addTo(map_5a74b5ad09a20b565cbc208db93f578b);
#
#
#         var popup_f95d1e5827c3c24198ab3aa51eaac4b6 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_c15bce35ff868e0ee1fb837d53c49d0c = $(`&lt;div id=&quot;html_c15bce35ff868e0ee1fb837d53c49d0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Bulgaria&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17bf3f050&gt;&lt;/div&gt;`)[0];
#                 popup_f95d1e5827c3c24198ab3aa51eaac4b6.setContent(html_c15bce35ff868e0ee1fb837d53c49d0c);
#
#
#
#         marker_6fadc07c397b4749d5a56c63e5c1b7c3.bindPopup(popup_f95d1e5827c3c24198ab3aa51eaac4b6)
#         ;
#
#
#
#
#             var marker_6065e6a632827a36c505e6e0015f580e = L.marker(
#                 [17.1204943, -88.6859028],
#                 {}
#             ).addTo(map_5a74b5ad09a20b565cbc208db93f578b);
#
#
#         var popup_cbd646d06dedf9fae61bb9751c2fcd82 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_bf019920aba44963f30281539529adcc = $(`&lt;div id=&quot;html_bf019920aba44963f30281539529adcc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Belize&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17bf07c50&gt;&lt;/div&gt;`)[0];
#                 popup_cbd646d06dedf9fae61bb9751c2fcd82.setContent(html_bf019920aba44963f30281539529adcc);
#
#
#
#         marker_6065e6a632827a36c505e6e0015f580e.bindPopup(popup_cbd646d06dedf9fae61bb9751c2fcd82)
#         ;
#
#
#
#
#             var marker_e06b1f2a0ffbcaa665ce1ac9af607176 = L.marker(
#                 [12.5013629, -69.9618475],
#                 {}
#             ).addTo(map_5a74b5ad09a20b565cbc208db93f578b);
#
#
#         var popup_63c8d18176b794bf3264c5cbf5e97bba = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_71c38c54ba3715f0380b27a27c51648d = $(`&lt;div id=&quot;html_71c38c54ba3715f0380b27a27c51648d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Aruba&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17b36d650&gt;&lt;/div&gt;`)[0];
#                 popup_63c8d18176b794bf3264c5cbf5e97bba.setContent(html_71c38c54ba3715f0380b27a27c51648d);
# ok
# test_get_lowest_migrant_countries (__main__.TestPopulationFunctions.test_get_lowest_migrant_countries)
# Tests the retrieval of the bottom 10 countries with the lowest net migrants. ...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e4e7aa646f1802e2158d3bb1d52d2e48 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e4e7aa646f1802e2158d3bb1d52d2e48&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e4e7aa646f1802e2158d3bb1d52d2e48 = L.map(
#                 &quot;map_e4e7aa646f1802e2158d3bb1d52d2e48&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f42f4a331330cf7948c73833a049df09 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f42f4a331330cf7948c73833a049df09.addTo(map_e4e7aa646f1802e2158d3bb1d52d2e48);
#
#
#             var marker_f3325465c5f80e9506fc843a6b356b5e = L.marker(
#                 [-5.6816069, 144.2489081],
#                 {}
#             ).addTo(map_e4e7aa646f1802e2158d3bb1d52d2e48);
#
#
#         var popup_b4d224c9a6392443dcf230bb2360096e = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_8863df9d7b7b60814eddf5e891bee191 = $(`&lt;div id=&quot;html_8863df9d7b7b60814eddf5e891bee191&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Papua New Guinea&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17c3d8950&gt;&lt;/div&gt;`)[0];
#                 popup_b4d224c9a6392443dcf230bb2360096e.setContent(html_8863df9d7b7b60814eddf5e891bee191);
#
#
#
#         marker_f3325465c5f80e9506fc843a6b356b5e.bindPopup(popup_b4d224c9a6392443dcf230bb2360096e)
#         ;
#
#
#
#
#             var marker_6bac633f5102fde746e6d92da3b5a454 = L.marker(
#                 [0.3448612, 173.6641773],
#                 {}
#             ).addTo(map_e4e7aa646f1802e2158d3bb1d52d2e48);
#
#
#         var popup_c8506c5fc4956ba419bd1c038992325b = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_f3ce1a2c0e98779a34943651a6e7ba0d = $(`&lt;div id=&quot;html_f3ce1a2c0e98779a34943651a6e7ba0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Kiribati&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17bfbccd0&gt;&lt;/div&gt;`)[0];
#                 popup_c8506c5fc4956ba419bd1c038992325b.setContent(html_f3ce1a2c0e98779a34943651a6e7ba0d);
#
#
#
#         marker_6bac633f5102fde746e6d92da3b5a454.bindPopup(popup_c8506c5fc4956ba419bd1c038992325b)
#         ;
#
#
#
#
#             var marker_a23942f23f15db7e9ac8e4ed11b2979e = L.marker(
#                 [-8.6405212, 179.1582918181797],
#                 {}
#             ).addTo(map_e4e7aa646f1802e2158d3bb1d52d2e48);
#
#
#         var popup_76451133b99f52e20215d9bbe2139edb = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_2ce27d702693504983355ab861e44ef3 = $(`&lt;div id=&quot;html_2ce27d702693504983355ab861e44ef3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Tuvalu&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17bf5b550&gt;&lt;/div&gt;`)[0];
#                 popup_76451133b99f52e20215d9bbe2139edb.setContent(html_2ce27d702693504983355ab861e44ef3);
#
#
#
#         marker_a23942f23f15db7e9ac8e4ed11b2979e.bindPopup(popup_76451133b99f52e20215d9bbe2139edb)
#         ;
#
#
#
#
#             var marker_f9b0e274dfdb18bda9084f4e21e8b591 = L.marker(
#                 [27.549511, 90.5119273],
#                 {}
#             ).addTo(map_e4e7aa646f1802e2158d3bb1d52d2e48);
#
#
#         var popup_0316692f8ae7c3dfc4d4f6a9cb23638a = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_99e5c30113d8b730e161cd0e34efe0f8 = $(`&lt;div id=&quot;html_99e5c30113d8b730e161cd0e34efe0f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Bhutan&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17bf487d0&gt;&lt;/div&gt;`)[0];
#                 popup_0316692f8ae7c3dfc4d4f6a9cb23638a.setContent(html_99e5c30113d8b730e161cd0e34efe0f8);
#
#
#
#         marker_f9b0e274dfdb18bda9084f4e21e8b591.bindPopup(popup_0316692f8ae7c3dfc4d4f6a9cb23638a)
#         ;
#
#
#
#
#             var marker_d4e99bc68f55e951766f19edaf90ab25 = L.marker(
#                 [15.4113138, -61.3653618],
#                 {}
#             ).addTo(map_e4e7aa646f1802e2158d3bb1d52d2e48);
#
#
#         var popup_fa522840741a0e133f7232932041c0fb = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_d8bf4b357cfd5016e0cbdcb74fc39634 = $(`&lt;div id=&quot;html_d8bf4b357cfd5016e0cbdcb74fc39634&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Dominica&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17bfd1790&gt;&lt;/div&gt;`)[0];
#                 popup_fa522840741a0e133f7232932041c0fb.setContent(html_d8bf4b357cfd5016e0cbdcb74fc39634);
# ok
#
# ----------------------------------------------------------------------
# Ran 2 tests in 186.949s
#
# OK

# %%
class TestPopulationFunctions(unittest.TestCase):
    """
    Unit tests for population-related functions, specifically focusing on fertility rates.
    """

    def test_get_highest_fertility_countries(self):
        """
        Tests the retrieval of the top 10 countries with the highest fertility rates.
        """
        cleaned_combined_data = clean_data()
        combined_df = combine_dataframes()
        country_iframes = create_country_iframes(combined_df)

        top_countries = get_highest_fertility_countries(cleaned_combined_data, country_iframes)

        top_original_countries = cleaned_combined_data.nlargest(10, 'Fertility_Rate')['Country'].tolist()

        self.assertListEqual(top_countries['Country'].tolist(), top_original_countries, "Top countries mismatch.")

    def test_get_lowest_fertility_countries(self):
        """
        Tests the retrieval of the bottom 10 countries with the lowest fertility rates.
        """
        cleaned_combined_data = clean_data()
        combined_df = combine_dataframes()
        country_iframes = create_country_iframes(combined_df)

        low_countries = get_lowest_fertility_countries(cleaned_combined_data, country_iframes)

        low_original_countries = cleaned_combined_data.nsmallest(10, 'Fertility_Rate')['Country'].tolist()

        self.assertListEqual(low_countries['Country'].tolist(), low_original_countries, "Low countries mismatch.")

def run_tests():
    """
    Runs all tests in the TestPopulationFunctions class.
    """
    suite = unittest.TestLoader().loadTestsFromTestCase(TestPopulationFunctions)
    unittest.TextTestRunner(verbosity=2, buffer=True).run(suite)

run_tests()
# Out:
# test_get_highest_fertility_countries (__main__.TestPopulationFunctions.test_get_highest_fertility_countries)
# Tests the retrieval of the top 10 countries with the highest fertility rates. ...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86a0f3c4c9095ac4a92c0bf622d8755f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86a0f3c4c9095ac4a92c0bf622d8755f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_86a0f3c4c9095ac4a92c0bf622d8755f = L.map(
#                 &quot;map_86a0f3c4c9095ac4a92c0bf622d8755f&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a0ef07bd7885e797fc336aaddaaec2c8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a0ef07bd7885e797fc336aaddaaec2c8.addTo(map_86a0f3c4c9095ac4a92c0bf622d8755f);
#
#
#             var marker_1d5ff73bff1457a0eb3a5932fb7007a6 = L.marker(
#                 [15.6134137, 19.0156172],
#                 {}
#             ).addTo(map_86a0f3c4c9095ac4a92c0bf622d8755f);
#
#
#         var popup_72c2a1f8c4af224768c879cca6d6a583 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_3027a9d9bd6775ed6ff54a21d4ecbf1e = $(`&lt;div id=&quot;html_3027a9d9bd6775ed6ff54a21d4ecbf1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Chad&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x1785cdf90&gt;&lt;/div&gt;`)[0];
#                 popup_72c2a1f8c4af224768c879cca6d6a583.setContent(html_3027a9d9bd6775ed6ff54a21d4ecbf1e);
#
#
#
#         marker_1d5ff73bff1457a0eb3a5932fb7007a6.bindPopup(popup_72c2a1f8c4af224768c879cca6d6a583)
#         ;
#
#
#
#
#             var marker_35ee01a0786685dac7d97f069c687aad = L.marker(
#                 [8.3676771, 49.083416],
#                 {}
#             ).addTo(map_86a0f3c4c9095ac4a92c0bf622d8755f);
#
#
#         var popup_b3eef2f48edd79a862501987ab095548 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_f2216e98141bc1f454c78ebfc7132585 = $(`&lt;div id=&quot;html_f2216e98141bc1f454c78ebfc7132585&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Somalia&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17cb3b790&gt;&lt;/div&gt;`)[0];
#                 popup_b3eef2f48edd79a862501987ab095548.setContent(html_f2216e98141bc1f454c78ebfc7132585);
#
#
#
#         marker_35ee01a0786685dac7d97f069c687aad.bindPopup(popup_b3eef2f48edd79a862501987ab095548)
#         ;
#
#
#
#
#             var marker_cf1746b9d32b959e5cf3a229753f5843 = L.marker(
#                 [7.0323598, 19.9981227],
#                 {}
#             ).addTo(map_86a0f3c4c9095ac4a92c0bf622d8755f);
#
#
#         var popup_0f8a76906d55671d44bed43f62ba9d31 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_304552644cd60b3bb62b5693f464719c = $(`&lt;div id=&quot;html_304552644cd60b3bb62b5693f464719c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Central African Republic&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17bfc88d0&gt;&lt;/div&gt;`)[0];
#                 popup_0f8a76906d55671d44bed43f62ba9d31.setContent(html_304552644cd60b3bb62b5693f464719c);
#
#
#
#         marker_cf1746b9d32b959e5cf3a229753f5843.bindPopup(popup_0f8a76906d55671d44bed43f62ba9d31)
#         ;
#
#
#
#
#             var marker_e1e119bf7f30ca7fb5f62c0e8cbb8cc4 = L.marker(
#                 [17.7356214, 9.3238432],
#                 {}
#             ).addTo(map_86a0f3c4c9095ac4a92c0bf622d8755f);
#
#
#         var popup_64d321282da27683867e87a77eac8dda = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_37d53de1a6a4e638a7e80f8fa2ea0eb1 = $(`&lt;div id=&quot;html_37d53de1a6a4e638a7e80f8fa2ea0eb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Niger&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17cb3a1d0&gt;&lt;/div&gt;`)[0];
#                 popup_64d321282da27683867e87a77eac8dda.setContent(html_37d53de1a6a4e638a7e80f8fa2ea0eb1);
#
#
#
#         marker_e1e119bf7f30ca7fb5f62c0e8cbb8cc4.bindPopup(popup_64d321282da27683867e87a77eac8dda)
#         ;
#
#
#
#
#             var marker_3c5ee1c86d8c0849db638fce069d2e3f = L.marker(
#                 [16.3700359, -2.2900239],
#                 {}
#             ).addTo(map_86a0f3c4c9095ac4a92c0bf622d8755f);
#
#
#         var popup_d788e4ddd01becf20f20160dc84e43d3 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_8d71a73aa84d4647afe2e3004d768d1d = $(`&lt;div id=&quot;html_8d71a73aa84d4647afe2e3004d768d1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Mali&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17c938150&gt;&lt;/div&gt;`)[0];
#                 popup_d788e4ddd01becf20f20160dc84e43d3.setContent(html_8d71a73aa84d4647afe2e3004d768d1d);
# ok
# test_get_lowest_fertility_countries (__main__.TestPopulationFunctions.test_get_lowest_fertility_countries)
# Tests the retrieval of the bottom 10 countries with the lowest fertility rates. ...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_893a5a599234b60d637a33479086f00b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_893a5a599234b60d637a33479086f00b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_893a5a599234b60d637a33479086f00b = L.map(
#                 &quot;map_893a5a599234b60d637a33479086f00b&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6864fb75914d20eb2b8390c7d922b925 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6864fb75914d20eb2b8390c7d922b925.addTo(map_893a5a599234b60d637a33479086f00b);
#
#
#             var marker_c3c6a064b27f284c5e18794c7281efc0 = L.marker(
#                 [49.4871968, 31.2718321],
#                 {}
#             ).addTo(map_893a5a599234b60d637a33479086f00b);
#
#
#         var popup_cde1f7b5f6c93a59c5051101c126c73a = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_6e8f81de8ec2a6bc29a92a224dbfe8d2 = $(`&lt;div id=&quot;html_6e8f81de8ec2a6bc29a92a224dbfe8d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Ukraine&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17bf44fd0&gt;&lt;/div&gt;`)[0];
#                 popup_cde1f7b5f6c93a59c5051101c126c73a.setContent(html_6e8f81de8ec2a6bc29a92a224dbfe8d2);
#
#
#
#         marker_c3c6a064b27f284c5e18794c7281efc0.bindPopup(popup_cde1f7b5f6c93a59c5051101c126c73a)
#         ;
#
#
#
#
#             var marker_cd21471c0292aec4e53a57927bbfc254 = L.marker(
#                 [-31.7613365, -71.3187697],
#                 {}
#             ).addTo(map_893a5a599234b60d637a33479086f00b);
#
#
#         var popup_55fda07208663201e72ed34083e96d51 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_467ebe1d5ab6c5cb80b2be2eb523ef6c = $(`&lt;div id=&quot;html_467ebe1d5ab6c5cb80b2be2eb523ef6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Chile&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17c351590&gt;&lt;/div&gt;`)[0];
#                 popup_55fda07208663201e72ed34083e96d51.setContent(html_467ebe1d5ab6c5cb80b2be2eb523ef6c);
#
#
#
#         marker_cd21471c0292aec4e53a57927bbfc254.bindPopup(popup_55fda07208663201e72ed34083e96d51)
#         ;
#
#
#
#
#             var marker_fcdc2e2c20ea70097592e29d373e5b2d = L.marker(
#                 [35.8885993, 14.4476911],
#                 {}
#             ).addTo(map_893a5a599234b60d637a33479086f00b);
#
#
#         var popup_4a4d347ff5978fbf57462b975ed82313 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_c0f7efd982e8cfcebf91ca14bbd42852 = $(`&lt;div id=&quot;html_c0f7efd982e8cfcebf91ca14bbd42852&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Malta&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17b5fb390&gt;&lt;/div&gt;`)[0];
#                 popup_4a4d347ff5978fbf57462b975ed82313.setContent(html_c0f7efd982e8cfcebf91ca14bbd42852);
#
#
#
#         marker_fcdc2e2c20ea70097592e29d373e5b2d.bindPopup(popup_4a4d347ff5978fbf57462b975ed82313)
#         ;
#
#
#
#
#             var marker_0fba7bc46bfad46dd1553f64314a2be6 = L.marker(
#                 [42.5407167, 1.5732033],
#                 {}
#             ).addTo(map_893a5a599234b60d637a33479086f00b);
#
#
#         var popup_e1ac0a6389697983634a4e71b2970c9b = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_9b4e69d50b9467e279d963af23ab14b0 = $(`&lt;div id=&quot;html_9b4e69d50b9467e279d963af23ab14b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Andorra&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17b553c50&gt;&lt;/div&gt;`)[0];
#                 popup_e1ac0a6389697983634a4e71b2970c9b.setContent(html_9b4e69d50b9467e279d963af23ab14b0);
#
#
#
#         marker_0fba7bc46bfad46dd1553f64314a2be6.bindPopup(popup_e1ac0a6389697983634a4e71b2970c9b)
#         ;
#
#
#
#
#             var marker_d8b67bf8044909cd278d2283128a7bb9 = L.marker(
#                 [36.5748441, 139.2394179],
#                 {}
#             ).addTo(map_893a5a599234b60d637a33479086f00b);
#
#
#         var popup_70e394f2324e897a032dc99d2503639d = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_73333941f22adbb3853163c87167ab15 = $(`&lt;div id=&quot;html_73333941f22adbb3853163c87167ab15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Japan&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17c935a10&gt;&lt;/div&gt;`)[0];
#                 popup_70e394f2324e897a032dc99d2503639d.setContent(html_73333941f22adbb3853163c87167ab15);
#
#
#
#         marker_
# ok
#
# ----------------------------------------------------------------------
# Ran 2 tests in 189.136s
#
# OK

# %%
class TestPopulationFunctions(unittest.TestCase):
    """Unit tests for population-related functions."""

    def test_get_oldest_countries(self):
        """Test that the function returns the countries with the highest median ages."""
        cleaned_combined_data = clean_data()
        combined_df = combine_dataframes()
        country_iframes = create_country_iframes(combined_df)

        top_countries = get_oldest_countries(cleaned_combined_data, country_iframes)

        top_original_countries = cleaned_combined_data.nlargest(10, 'Median_age')['Country'].tolist()

        self.assertListEqual(top_countries['Country'].tolist(), top_original_countries, "Top countries mismatch.")

    def test_get_youngest_countries(self):
        """Test that the function returns the countries with the lowest median ages."""
        cleaned_combined_data = clean_data()
        combined_df = combine_dataframes()
        country_iframes = create_country_iframes(combined_df)

        low_countries = get_youngest_countries(cleaned_combined_data, country_iframes)

        low_original_countries = cleaned_combined_data.nsmallest(10, 'Median_age')['Country'].tolist()

        self.assertListEqual(low_countries['Country'].tolist(), low_original_countries, "Low countries mismatch.")

def run_tests():
    """Run the test suite for the population functions."""
    suite = unittest.TestLoader().loadTestsFromTestCase(TestPopulationFunctions)
    unittest.TextTestRunner(verbosity=2, buffer=True).run(suite)

run_tests()
# Out:
# test_get_oldest_countries (__main__.TestPopulationFunctions.test_get_oldest_countries)
# Test that the function returns the countries with the highest median ages. ...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2a467ff8bbf02910541c97096f23163a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2a467ff8bbf02910541c97096f23163a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2a467ff8bbf02910541c97096f23163a = L.map(
#                 &quot;map_2a467ff8bbf02910541c97096f23163a&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_67a0caac49240323efcf1680e238eeba = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_67a0caac49240323efcf1680e238eeba.addTo(map_2a467ff8bbf02910541c97096f23163a);
#
#
#             var marker_8b34dee3bee4b7c3afdb88e8c2790623 = L.marker(
#                 [36.5748441, 139.2394179],
#                 {}
#             ).addTo(map_2a467ff8bbf02910541c97096f23163a);
#
#
#         var popup_1a5464eb24c827c577e865db0f902aaa = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_8ed7afcf6e25c76830cecb46632a2f35 = $(`&lt;div id=&quot;html_8ed7afcf6e25c76830cecb46632a2f35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Japan&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17c0b9b90&gt;&lt;/div&gt;`)[0];
#                 popup_1a5464eb24c827c577e865db0f902aaa.setContent(html_8ed7afcf6e25c76830cecb46632a2f35);
#
#
#
#         marker_8b34dee3bee4b7c3afdb88e8c2790623.bindPopup(popup_1a5464eb24c827c577e865db0f902aaa)
#         ;
#
#
#
#
#             var marker_3ffc9c80e8268134accf9f1846980908 = L.marker(
#                 [42.6384261, 12.674297],
#                 {}
#             ).addTo(map_2a467ff8bbf02910541c97096f23163a);
#
#
#         var popup_0ab780dc3d0e9840870f9307fc5f7684 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_a9c8a3b1311a9d1ba3980c9464bbe570 = $(`&lt;div id=&quot;html_a9c8a3b1311a9d1ba3980c9464bbe570&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Italy&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17c0f9c50&gt;&lt;/div&gt;`)[0];
#                 popup_0ab780dc3d0e9840870f9307fc5f7684.setContent(html_a9c8a3b1311a9d1ba3980c9464bbe570);
#
#
#
#         marker_3ffc9c80e8268134accf9f1846980908.bindPopup(popup_0ab780dc3d0e9840870f9307fc5f7684)
#         ;
#
#
#
#
#             var marker_df4a546bcca612d970743d22d0f76e83 = L.marker(
#                 [43.9458623, 12.458306],
#                 {}
#             ).addTo(map_2a467ff8bbf02910541c97096f23163a);
#
#
#         var popup_e2cd49492b701f8f4951b7e2edf6a9af = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_c34fcebd869c9041062b2e34879a8654 = $(`&lt;div id=&quot;html_c34fcebd869c9041062b2e34879a8654&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;San Marino&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17c76c810&gt;&lt;/div&gt;`)[0];
#                 popup_e2cd49492b701f8f4951b7e2edf6a9af.setContent(html_c34fcebd869c9041062b2e34879a8654);
#
#
#
#         marker_df4a546bcca612d970743d22d0f76e83.bindPopup(popup_e2cd49492b701f8f4951b7e2edf6a9af)
#         ;
#
#
#
#
#             var marker_800dbc35816e2f695808170fc2bb8724 = L.marker(
#                 [39.6621648, -8.1353519],
#                 {}
#             ).addTo(map_2a467ff8bbf02910541c97096f23163a);
#
#
#         var popup_89ca2eee29f750a8c599588e62667911 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_2016292e78d23bf274e1aa8922af37e6 = $(`&lt;div id=&quot;html_2016292e78d23bf274e1aa8922af37e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Portugal&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17c6a9050&gt;&lt;/div&gt;`)[0];
#                 popup_89ca2eee29f750a8c599588e62667911.setContent(html_2016292e78d23bf274e1aa8922af37e6);
#
#
#
#         marker_800dbc35816e2f695808170fc2bb8724.bindPopup(popup_89ca2eee29f750a8c599588e62667911)
#         ;
#
#
#
#
#             var marker_8060dd92101fa8bbb59dcc83355370c4 = L.marker(
#                 [38.9953683, 21.9877132],
#                 {}
#             ).addTo(map_2a467ff8bbf02910541c97096f23163a);
#
#
#         var popup_088c9bbd1713e3bee4bd5087412248fe = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_f8fcf473ad7bd3ed77e775cc183faab5 = $(`&lt;div id=&quot;html_f8fcf473ad7bd3ed77e775cc183faab5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Greece&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17c793090&gt;&lt;/div&gt;`)[0];
#                 popup_088c9bbd1713e3bee4bd5087412248fe.setContent(html_f8fcf473ad7bd3ed77e775cc183faab5);
#
#
#
#         marke
# ok
# test_get_youngest_countries (__main__.TestPopulationFunctions.test_get_youngest_countries)
# Test that the function returns the countries with the lowest median ages. ...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5952e758aa5d57e5e5cdb21ba6003991 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5952e758aa5d57e5e5cdb21ba6003991&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5952e758aa5d57e5e5cdb21ba6003991 = L.map(
#                 &quot;map_5952e758aa5d57e5e5cdb21ba6003991&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9bfadabb7c7059a5605b636c547425b2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9bfadabb7c7059a5605b636c547425b2.addTo(map_5952e758aa5d57e5e5cdb21ba6003991);
#
#
#             var marker_9ce47abd80cead7067499c5b3bf6412e = L.marker(
#                 [7.0323598, 19.9981227],
#                 {}
#             ).addTo(map_5952e758aa5d57e5e5cdb21ba6003991);
#
#
#         var popup_629cf96ea1b414108dd5430888f37167 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_7707e64f3b08e08bc23b657805bbf973 = $(`&lt;div id=&quot;html_7707e64f3b08e08bc23b657805bbf973&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Central African Republic&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17b335d90&gt;&lt;/div&gt;`)[0];
#                 popup_629cf96ea1b414108dd5430888f37167.setContent(html_7707e64f3b08e08bc23b657805bbf973);
#
#
#
#         marker_9ce47abd80cead7067499c5b3bf6412e.bindPopup(popup_629cf96ea1b414108dd5430888f37167)
#         ;
#
#
#
#
#             var marker_f034675fc6b8efe5bfca32b2c434bc7b = L.marker(
#                 [17.7356214, 9.3238432],
#                 {}
#             ).addTo(map_5952e758aa5d57e5e5cdb21ba6003991);
#
#
#         var popup_c074dd95ac9733d8c4b4ba0b1de22cd0 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_a5332b7aab7d9ba053830f25f50442d3 = $(`&lt;div id=&quot;html_a5332b7aab7d9ba053830f25f50442d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Niger&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17b38ff50&gt;&lt;/div&gt;`)[0];
#                 popup_c074dd95ac9733d8c4b4ba0b1de22cd0.setContent(html_a5332b7aab7d9ba053830f25f50442d3);
#
#
#
#         marker_f034675fc6b8efe5bfca32b2c434bc7b.bindPopup(popup_c074dd95ac9733d8c4b4ba0b1de22cd0)
#         ;
#
#
#
#
#             var marker_14ef3976138dbe20476a529a07209603 = L.marker(
#                 [-19.302233, 34.9144977],
#                 {}
#             ).addTo(map_5952e758aa5d57e5e5cdb21ba6003991);
#
#
#         var popup_0aba195ad2dfd0cd8bffd26306d6000e = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_3f4ef65c0e594144345c68616a21535d = $(`&lt;div id=&quot;html_3f4ef65c0e594144345c68616a21535d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Mozambique&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17b512650&gt;&lt;/div&gt;`)[0];
#                 popup_0aba195ad2dfd0cd8bffd26306d6000e.setContent(html_3f4ef65c0e594144345c68616a21535d);
#
#
#
#         marker_14ef3976138dbe20476a529a07209603.bindPopup(popup_0aba195ad2dfd0cd8bffd26306d6000e)
#         ;
#
#
#
#
#             var marker_0773552d59546686cac78a05d96f63ce = L.marker(
#                 [16.3700359, -2.2900239],
#                 {}
#             ).addTo(map_5952e758aa5d57e5e5cdb21ba6003991);
#
#
#         var popup_f731860a6bf46f36fd4b92078c2eac77 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_8780025e60ee1f3c0d079129f89d4794 = $(`&lt;div id=&quot;html_8780025e60ee1f3c0d079129f89d4794&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Mali&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17c3f9cd0&gt;&lt;/div&gt;`)[0];
#                 popup_f731860a6bf46f36fd4b92078c2eac77.setContent(html_8780025e60ee1f3c0d079129f89d4794);
#
#
#
#         marker_0773552d59546686cac78a05d96f63ce.bindPopup(popup_f731860a6bf46f36fd4b92078c2eac77)
#         ;
#
#
#
#
#             var marker_493eee6c4495b8c12e887a8ea052bd45 = L.marker(
#                 [15.6134137, 19.0156172],
#                 {}
#             ).addTo(map_5952e758aa5d57e5e5cdb21ba6003991);
#
#
#         var popup_2f9e89f501539b7990790b8198948a2d = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_9366e7631f68d800b45d9999b6dc66e0 = $(`&lt;div id=&quot;html_9366e7631f68d800b45d9999b6dc66e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Chad&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17af667d0&gt;&lt;/div&gt;`)[0];
#                 popup_2f9e89f501539b7990790b8198948a2d.setContent(html_9366e7631f68d800b45d9999b6dc66e0);
# ok
#
# ----------------------------------------------------------------------
# Ran 2 tests in 188.809s
#
# OK

# %%
class TestPopulationFunctions(unittest.TestCase):
    """Unit tests for functions that analyze countries based on wealth metrics."""

    def test_get_richest_countries(self):
        """Test that the function returns the countries with the highest GDP for 2024."""
        cleaned_combined_data = clean_data()
        combined_df = combine_dataframes()
        country_iframes = create_country_iframes(combined_df)

        top_countries = get_richest_countries(cleaned_combined_data, country_iframes)

        top_original_countries = cleaned_combined_data.nlargest(10, 'GDP_2024')['Country'].tolist()

        self.assertListEqual(top_countries['Country'].tolist(), top_original_countries, "Top countries mismatch.")

    def test_get_most_poor_countries(self):
        """Test that the function returns the countries with the lowest GDP for 2024."""
        cleaned_combined_data = clean_data()
        combined_df = combine_dataframes()
        country_iframes = create_country_iframes(combined_df)

        low_countries = get_most_poor_countries(cleaned_combined_data, country_iframes)

        low_original_countries = cleaned_combined_data.nsmallest(10, 'GDP_2024')['Country'].tolist()

        self.assertListEqual(low_countries['Country'].tolist(), low_original_countries, "Low countries mismatch.")

def run_tests():
    """Run the test suite for the population functions."""
    suite = unittest.TestLoader().loadTestsFromTestCase(TestPopulationFunctions)
    unittest.TextTestRunner(verbosity=2, buffer=True).run(suite)

run_tests()
# Out:
# test_get_most_poor_countries (__main__.TestPopulationFunctions.test_get_most_poor_countries)
# Test that the function returns the countries with the lowest GDP for 2024. ...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a6181532de0710d708045e6eaa732dd0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a6181532de0710d708045e6eaa732dd0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a6181532de0710d708045e6eaa732dd0 = L.map(
#                 &quot;map_a6181532de0710d708045e6eaa732dd0&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2aa13b2dea444bc3c8e860b176d71cab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2aa13b2dea444bc3c8e860b176d71cab.addTo(map_a6181532de0710d708045e6eaa732dd0);
#
#
#             var marker_7e1c86a84e780849b5b730f800a15e83 = L.marker(
#                 [10.9, 6.5],
#                 {}
#             ).addTo(map_a6181532de0710d708045e6eaa732dd0);
#
#
#         var popup_0f0b2c5aa7b2cededded9ec8a80e74be = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_f8fb037d9b4e6a39f38ef97de144caea = $(`&lt;div id=&quot;html_f8fb037d9b4e6a39f38ef97de144caea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Sudan&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17caf5910&gt;&lt;/div&gt;`)[0];
#                 popup_0f0b2c5aa7b2cededded9ec8a80e74be.setContent(html_f8fb037d9b4e6a39f38ef97de144caea);
#
#
#
#         marker_7e1c86a84e780849b5b730f800a15e83.bindPopup(popup_0f0b2c5aa7b2cededded9ec8a80e74be)
#         ;
#
#
#
#
#             var marker_37585dfc968a8aecd959c927898d1d18 = L.marker(
#                 [19.1399952, -72.3570972],
#                 {}
#             ).addTo(map_a6181532de0710d708045e6eaa732dd0);
#
#
#         var popup_54e29a7eb34ae63d552d925959745ec9 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_615886e762e3cd4d814c620e1651e00f = $(`&lt;div id=&quot;html_615886e762e3cd4d814c620e1651e00f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Haiti&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17c461b50&gt;&lt;/div&gt;`)[0];
#                 popup_54e29a7eb34ae63d552d925959745ec9.setContent(html_615886e762e3cd4d814c620e1651e00f);
#
#
#
#         marker_37585dfc968a8aecd959c927898d1d18.bindPopup(popup_54e29a7eb34ae63d552d925959745ec9)
#         ;
#
#
#
#
#             var marker_542cee46bc4f4a28af562d793fa60f72 = L.marker(
#                 [-34.9964963, -64.9672817],
#                 {}
#             ).addTo(map_a6181532de0710d708045e6eaa732dd0);
#
#
#         var popup_8f42c64a54c3cf5206bed8ea7c3fd6bb = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_ac37a1705c8dd64a17d9d49f8fbb4df3 = $(`&lt;div id=&quot;html_ac37a1705c8dd64a17d9d49f8fbb4df3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Argentina&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17b4dce90&gt;&lt;/div&gt;`)[0];
#                 popup_8f42c64a54c3cf5206bed8ea7c3fd6bb.setContent(html_ac37a1705c8dd64a17d9d49f8fbb4df3);
#
#
#
#         marker_542cee46bc4f4a28af562d793fa60f72.bindPopup(popup_8f42c64a54c3cf5206bed8ea7c3fd6bb)
#         ;
#
#
#
#
#             var marker_1dec4943ff3eaf16531a5a2c4a9d92a2 = L.marker(
#                 [29.3796532, 47.9734174],
#                 {}
#             ).addTo(map_a6181532de0710d708045e6eaa732dd0);
#
#
#         var popup_cc2660f82b54ac74cf1d67c90f94582f = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_f5904386a47ac50d9354a5a5df60805d = $(`&lt;div id=&quot;html_f5904386a47ac50d9354a5a5df60805d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Kuwait&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17b3e5f90&gt;&lt;/div&gt;`)[0];
#                 popup_cc2660f82b54ac74cf1d67c90f94582f.setContent(html_f5904386a47ac50d9354a5a5df60805d);
#
#
#
#         marker_1dec4943ff3eaf16531a5a2c4a9d92a2.bindPopup(popup_cc2660f82b54ac74cf1d67c90f94582f)
#         ;
#
#
#
#
#             var marker_5df781c108983e2a292f25562f306a30 = L.marker(
#                 [16.3471243, 47.8915271],
#                 {}
#             ).addTo(map_a6181532de0710d708045e6eaa732dd0);
#
#
#         var popup_543863146b518f8707367ce2291bc7c4 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_c94f676a89546a62ec3abc0aee2d1a16 = $(`&lt;div id=&quot;html_c94f676a89546a62ec3abc0aee2d1a16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Yemen&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17b3f1650&gt;&lt;/div&gt;`)[0];
#                 popup_543863146b518f8707367ce2291bc7c4.setContent(html_c94f676a89546a62ec3abc0aee2d1a16);
#
#
#
#         marker_5df781c1089
# ok
# test_get_richest_countries (__main__.TestPopulationFunctions.test_get_richest_countries)
# Test that the function returns the countries with the highest GDP for 2024. ...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2b75b4afc281d6486c7ce76176428ac1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2b75b4afc281d6486c7ce76176428ac1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2b75b4afc281d6486c7ce76176428ac1 = L.map(
#                 &quot;map_2b75b4afc281d6486c7ce76176428ac1&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_808c66e2f892af18250b5921390daeac = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_808c66e2f892af18250b5921390daeac.addTo(map_2b75b4afc281d6486c7ce76176428ac1);
#
#
#             var marker_3a4e15310f3ef5786902931a010cf28d = L.marker(
#                 [4.8417097, -58.6416891],
#                 {}
#             ).addTo(map_2b75b4afc281d6486c7ce76176428ac1);
#
#
#         var popup_816ed23dc6fb5dbc1a16a1a4ef850173 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_790f195a8beb7f0a693233f637e85079 = $(`&lt;div id=&quot;html_790f195a8beb7f0a693233f637e85079&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Guyana&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17ce9fc90&gt;&lt;/div&gt;`)[0];
#                 popup_816ed23dc6fb5dbc1a16a1a4ef850173.setContent(html_790f195a8beb7f0a693233f637e85079);
#
#
#
#         marker_3a4e15310f3ef5786902931a010cf28d.bindPopup(popup_816ed23dc6fb5dbc1a16a1a4ef850173)
#         ;
#
#
#
#
#             var marker_a8c647abb55e02de5c1c557cbbb552bb = L.marker(
#                 [17.7356214, 9.3238432],
#                 {}
#             ).addTo(map_2b75b4afc281d6486c7ce76176428ac1);
#
#
#         var popup_abdbba508f0ba3a33f0d9b29a24137d3 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_1f190462d7ee2881a05203a1d9bf1622 = $(`&lt;div id=&quot;html_1f190462d7ee2881a05203a1d9bf1622&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Niger&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17ca80310&gt;&lt;/div&gt;`)[0];
#                 popup_abdbba508f0ba3a33f0d9b29a24137d3.setContent(html_1f190462d7ee2881a05203a1d9bf1622);
#
#
#
#         marker_a8c647abb55e02de5c1c557cbbb552bb.bindPopup(popup_abdbba508f0ba3a33f0d9b29a24137d3)
#         ;
#
#
#
#
#             var marker_712920c2d743a566d6d21158abd44a1c = L.marker(
#                 [14.4750607, -14.4529612],
#                 {}
#             ).addTo(map_2b75b4afc281d6486c7ce76176428ac1);
#
#
#         var popup_affbb097a793c1a6f200624c184e7459 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_3393d222f11f8903a42790bd985db900 = $(`&lt;div id=&quot;html_3393d222f11f8903a42790bd985db900&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Senegal&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17cea1450&gt;&lt;/div&gt;`)[0];
#                 popup_affbb097a793c1a6f200624c184e7459.setContent(html_3393d222f11f8903a42790bd985db900);
#
#
#
#         marker_712920c2d743a566d6d21158abd44a1c.bindPopup(popup_affbb097a793c1a6f200624c184e7459)
#         ;
#
#
#
#
#             var marker_75b3bb955f95af81a3e69ae5c72e0746 = L.marker(
#                 [26.8234472, 18.1236723],
#                 {}
#             ).addTo(map_2b75b4afc281d6486c7ce76176428ac1);
#
#
#         var popup_9cd3beac4574ed1a7ddd0c14ef5a5a79 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_5f7ee255a9a327c51b05ad3352b0721b = $(`&lt;div id=&quot;html_5f7ee255a9a327c51b05ad3352b0721b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Libya&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17cdf05d0&gt;&lt;/div&gt;`)[0];
#                 popup_9cd3beac4574ed1a7ddd0c14ef5a5a79.setContent(html_5f7ee255a9a327c51b05ad3352b0721b);
#
#
#
#         marker_75b3bb955f95af81a3e69ae5c72e0746.bindPopup(popup_9cd3beac4574ed1a7ddd0c14ef5a5a79)
#         ;
#
#
#
#
#             var marker_e4d418f71b1137bcb64136b14f889c66 = L.marker(
#                 [-1.9646631, 30.0644358],
#                 {}
#             ).addTo(map_2b75b4afc281d6486c7ce76176428ac1);
#
#
#         var popup_2d64e61d48eb217a55d1dfe75756c7a3 = L.popup({&quot;maxWidth&quot;: 700});
#
#
#
#                 var html_f2ce9233a94e71d1860abe7441624899 = $(`&lt;div id=&quot;html_f2ce9233a94e71d1860abe7441624899&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Rwanda&lt;/b&gt;&lt;br&gt;&lt;branca.element.IFrame object at 0x17c369d50&gt;&lt;/div&gt;`)[0];
#                 popup_2d64e61d48eb217a55d1dfe75756c7a3.setContent(html_f2ce9233a94e71d1860abe7441624899);
#
#
#
#         marker_e4
# ok
#
# ----------------------------------------------------------------------
# Ran 2 tests in 187.635s
#
# OK

# %%
import time
import unittest

class TestDashboardPerformance(unittest.TestCase):
    """Unit tests for measuring the performance of dashboard creation."""

    def test_create_dashboard_performance(self):
        """Test the execution time of the create_dashboard function."""
        start_time = time.time()
        create_dashboard()
        end_time = time.time()
        execution_time = end_time - start_time

        print(f"Time taken to execute create_dashboard: {execution_time} seconds")

        
        threshold_time = 60

        
        self.assertLessEqual(execution_time, threshold_time, f"Execution time {execution_time} exceeds the threshold of {threshold_time} seconds")

def run_tests():
    """Run the test suite for dashboard performance tests."""
    suite = unittest.TestSuite()
    loader = unittest.TestLoader()
    suite.addTests(loader.loadTestsFromTestCase(TestDashboardPerformance))

    runner = unittest.TextTestRunner(verbosity=2)
    runner.run(suite)

run_tests()
# Out:
# test_create_dashboard_performance (__main__.TestDashboardPerformance.test_create_dashboard_performance)
# Test the execution time of the create_dashboard function. ...
# Dropdown(description='Select Criteria:', options=('High Population', 'Low Population', 'Top Crowded', 'Least C…
# Output()
# ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 4.864s
#
# OK
# Time taken to execute create_dashboard: 4.861050128936768 seconds
